# %%
import pandas as pd  
import string
path = "data.csv"
#buka file
data = pd.read_csv(path, error_bad_lines=False)
#tampilkan data array index addres_sap
databaru = data['address_sap']
databaru
for list in databaru:
    if 'JL' in list:
        print(list)
# Out:
# JL. SROGO - PLANTARAN NO. 5 RT, 03 RW. 04 KALIWUNGU SELATAN KENDAL
# JL. DELIKO V/ 59 SALATIGA -
# JL. BOUGENVILE I NO. 08 ( BLKG BKKBN ) KUPANG AMBARAWA
# JL. JOGOLOYO NO. 67 JOGOLOYO WONOSALAM DEMAK
# JL. PALEBON RAYA NO. 184 SEMARANG -
# JL. GANG BARU  106  SEMARANG -
# JL. GANG BARU 12  SEMARANG -
# JL. GANG BARU 124 SEMARANG -
# JL. GANG BARU 63 - SEMARANG -
# JL. GANG BARU 68  -  SEMARANG -
# JL. GANG BARU NO.74 SEMARANG -
# JL. GANG BARU NO.77  SEMARANG -
# JL. BRUMBUNG NO. 19 RT. 1 RW. 03 MRANGGEN DEMAK
# JL. BRUMBUNG RT. 01 RW. 2 MRANGGEN -
# JL. RAYA SEKARAN GG. JERUK NO. 5 RT. 003 RW. 002 GUNUNG PATI SEMARANG
# JL. MENOREH TENGAH III / 17B SEMARANG -
# JL. TALANG SENDANG I RT. 001 RW. 002 BENDAN DUWUR SEMARANG
# JL. CEMPAKA SARI TIMUR NO. 85 SEKARAN SEMARANG
# JL. FLAMBOYAN BLOK M-14 RT. 004 RW. 005 KATONSARI DEMAK
# JL. LAMONGAN RAYA 8A SEMARANG -
# JL. KYAI PALEMBAN DEMAK -
# JL. MENTERI SUPENO I/1 SEMARANG SEMARANG MUGASSARI
# ...

# %%
data
# Out:
#          CustNo Branch SDN Name  LATITUDE   LONGITUDE  \
# 0    5810031033    SDN Semarang -6.967570  110.236146
# 1    5810011499    SDN Semarang -7.302186  110.489872
# 2    5810011827    SDN Semarang -7.253485  110.413328
# 3    5810035547    SDN Semarang -6.912414  110.633265
# 4    5810011873    SDN Semarang -7.006627  110.466314
# 5    5810011801    SDN Semarang -6.976455  110.425670
# 6    5810011802    SDN Semarang -6.976455  110.425670
# 7    5810011803    SDN Semarang -6.976455  110.425670
# 8    5810011804    SDN Semarang -6.976455  110.425670
# 9    5810011891    SDN Semarang -6.976455  110.425670
# 10   5810011805    SDN Semarang -6.976455  110.425670
# 11   5810012190    SDN Semarang -6.976455  110.425670
# 12   5810032232    SDN Semarang -6.976487  110.427512
# 13   5810019118    SDN Semarang -6.919686  110.205597
# 14   5810035853    SDN Semarang -7.021771  110.513790
# 15   5810035734    SDN Semarang -7.021771  110.513790
# ...
